# %%
import horns 
from horns import parallel_analysis

data = z_phasic_traces

m = parallel_analysis(data, n_iter=100, method='minres', random_state=42)

print(f'\noptimal number of factors for FA: {m}\n')
# Out:
# Running cells with 'horns_env (Python 3.12.13)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n horns_env ipykernel --update-deps --force-reinstall'
