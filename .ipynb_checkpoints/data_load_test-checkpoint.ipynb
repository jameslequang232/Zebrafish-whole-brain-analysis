# %%
import sys 
import os

# %%
help(read_data)
# Out:
# Help on function read_data in module utils.data_io:
#
# read_data(fish, dir_voluseg)
#     Load voluseg-processed timeseries, cell coordinates, and volume mean.
#
#     Reads from: dir_voluseg / proj_ID / expt_ID / output /
#         - cells0_clean.hdf5  (cell_timeseries, cell_x, cell_y, cell_z)
#         - volume0.hdf5       (volume_mean)
#
#     Parameters
#     ----------
#     fish : tuple of (str, str)
#         (proj_ID, expt_ID).
#     dir_voluseg : str
#         Base path to voluseg data tree (config.dir_voluseg).
#
#     Returns
#     -------
#     data_np : np.ndarray
#         Cell timeseries, shape (n_cells, n_timepoints).
#     volume_mean : np.ndarray
#         Mean volume, transposed to (X, Y, Z).
#     cell_x, cell_y, cell_z : np.ndarray
#         Cell coordinates. NOTE: voluseg's cell_y maps to conceptual X,
#         and voluseg's cell_x maps to conceptual Y (axis swap applied here).

# %%
from pathlib import Path
from utils.data_io import read_data
sys.path.append('./Zebrafish-whole-brain-analysis')

#Paths

proj_ID = "hcrt-trpv1_huc-h2b-g8m_csn_120min"

#ID for each fish
expt_ID = " 251008_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish4"
#expt_ID = "251102_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish1"
#expt_ID = "251102_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish2"
#expt_ID = "251210_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish1"
#expt_ID = "251210_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish2"
#expt_ID = "251210_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish3"
#expt_ID = "260514_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish1"
#expt_ID = "260514_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish2"
#expt_ID = "260515_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish1"

dir_voluseg = '/mnt/storage-raid10/Yun'

fish = (proj_ID, expt_ID)

#when ready

try:
    cell_timeseries, cell_x, cell_y, cell_z, volume_mean = read_data(fish, dir_voluseg)
    print("Success")
    print(f"cell timeseries shape:{cell_timeseries.shape}")
    print(f"volume mean shape: {volume_mean.shape}")
    print(f"number of cells {len(cell_x)}")
except FileNotFoundError as e:
    print(f"File not ready {e}")
# Out:
# File not ready [Errno 2] Unable to synchronously open file (unable to open file: name = '/mnt/storage-raid10/Yun/hcrt-trpv1_huc-h2b-g8m_csn_120min/ 251008_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish4/output/cells0_clean.hdf5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
import os


project_path = '/mnt/storage-raid10/Yun/hcrt-trpv1_huc-h2b-g8m_csn_120min/'
if os.path.exists(project_path):
    print("Available Fish Folders")
    print(os.listdir(project_path))
else:
    print(f"Error: The base project path {project_path} doesn't exist yet.")

fish_path = os.path.join(project_path, '251008_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish4')
if os.path.exists(fish_path):
    print("\nInside Fish 4 Folder")
    print(os.listdir(fish_path))
    
    output_path = os.path.join(fish_path, 'output')
    if os.path.exists(output_path):
        print("\nInside Output Folder")
        print(os.listdir(output_path))
    else:
        print("\nStatus: The 'output' folder has not been created yet.")
else:
    print(f"\nStatus: The folder '251008_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish4' does not exist yet.")
# Out:
# Available Fish Folders
# ['.ipynb_checkpoints', '251008_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish4', '251102_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish1', '251102_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish2', '251210_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish1', '251210_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish2', '251210_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish3', '260514_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish1', '260514_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish2', '260515_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish1']
#
# Inside Fish 4 Folder
# ['.ipynb_checkpoints', '488_50uW_1xbin_1sec_250um_40slices_dmso45_10uMcsn45_dmso30_1', 'HR_Values.csv', 'input', 'output', 'tail_488_50uW_1xbin_1sec_250um_40slices_dmso45_10uMcsn45_dmso30_1', 'temp.txt']
#
# Inside Output Folder
# ['mask_plots', 'transforms']

# %%
from utils.data_io import read_data

fish = ("hcrt-trpv1_huc-h2b-g8m_csn_120min", "260514_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish1")
dir_voluseg = "/mnt/storage-raid10/Yun"

cell_timeseries, volume_mean, cell_x, cell_y, cell_z = read_data(fish, dir_voluseg)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 6
#       2
#       3 fish = ("hcrt-trpv1_huc-h2b-g8m_csn_120min", "260514_hcrt-trpv1_huc-h2b-g8m_csn_10uM_fish1")
#       4 dir_voluseg = "/mnt/storage-raid10/Yun"
#       5
# ----> 6 cell_timeseries, volume_mean, cell_x, cell_y, cell_z = read_data(fish, dir_voluseg)
#
# File /ssd-pool/james/lightsheet/Zebrafish-whole-brain-analysis/utils/data_io.py:79, in read_data(fish, dir_voluseg)
#      77 # --- cell timeseries and coordinates ---
#      78 cells_path = output_dir / "cells0_clean.hdf5"
# ---> 79 with h5py.File(str(cells_path), "r") as cells:
#      80     data_np = pd.DataFrame(cells["cell_timeseries"]).to_numpy()
#      81     # voluseg axis convention swap:
#
# ...
